# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen

# %%
url = "https://www.sw-ka.de/de/essen/"
page = urlopen(url)
html = page.read().decode("utf-8")
soup = BeautifulSoup(html, "html.parser")

# %%
results = soup.find(id="fragment-c1-1")

# %%
print(results.prettify())
# Out:
# <div class="ui-tabs-panel" id="fragment-c1-1" style="margin-bottom:0px;padding:8px 0px 0px 0px;border-bottom:none">
#  <table border="0" cellpadding="0" cellspacing="0" width="100%">
#   <tr>
#    <td class="mensatype" style="white-space: normal !important;">
#     <div>
#      Linie 1
#      <br/>
#      To-Go
#      <!-- l1 # adenauerring -->
#     </div>
#    </td>
#    <td class="mensadata">
#     <table border="0" cellpadding="0" cellspacing="0" class="easy-tab-dot">
#      <tr class="mt-1">
#       <td class="mtd-icon">
#        <div>
#         <img class="mealicon_2" src="/layout/icons/s_2.gif"/>
#         <br/>
#        </div>
#       </td>
#       <td class="first" valign="top">
#        <span class="bg">
#         <b>
#          Schweinebraten
#         </b>
#         <span>
#          Kartoffelpüree Zwiebelsoße
#         </span>
#        </span>
#        <sup>
#         [2,3,5,Ge,ML,Se,We]
#        </sup>
#       </td>
#       <td style="text-align: right;vertical-align:bottom;">
#        <span class="bgp price_1">
#         2,60 €
#        </span>
#        <span class="bgp price_2">
#         4,00 €
#        </span>
#        <span class="bgp price_3">
#         3,50 €
#        </span>
#        <span class="bgp price_4">
#         2,95 €
#        </span>
#       </td>
#      </tr>
#      <tr class="mt-6">
#       <td class="mtd-icon">
#        <div>
#         <img class="mealicon_2" src="/layout/icons/vegan_2.gif"/>
#         <br/>
#        </div>
#       </td>
#       <td class="first" valign="top">
#        <span class="bg">
#         <b>
#          Gemüseschnitzel mit Sweet Chilisoße und Duftreis
#         </b>
#        </span>
#        <sup>
#         [Sa,Se,So,We]
#        </sup>
#       </td>
#       <td style="text-align: right;vertical-align:bottom;">
#        <span class="bgp price_1">
#         2,60 €
#        </span>
#        <span class="bgp price_2">
#         4,00 €
#        </span>
#        <span class="bgp price_3">
#         3,50 €
#        </span>
#        <span class="bgp price_4">
#         2,95 €
#        </span>
#       </td>
#      </tr>
#      <tr class="mt-7">
#       <td class="mtd-icon">
#        <div>
#         <img class="mealicon_2" src="/layout/icons/vegetarian_2.gif"/>
#         <br/>
#        </div>
#       </td>
#       <td class="first" style="background:white;" valign="top">
#        <span class="bg">
#         <b>
#          zu jedem Gericht ein Birnenquark oder Obst
#         </b>
#        </span>
#        <sup>
#         [ML]
#        </sup>
#       </td>
#       <td style="text-align: right;vertical-align:bottom;background:white;">
#        <span class="bgp price_1">
#        </span>
#        <span class="bgp price_2">
#        </span>
#        <span class="bgp price_3">
#        </span>
#        <span class="bgp price_4">
#        </span>
#       </td>
#      </tr>
#     </table>
#    </td>
#   </tr>
#   <tr>
#    <td class="mensatype" style="white-space: normal !important;">
#     <div>
#      Linie 2
#      <br/>
#      BOOK A MENSA
#      <!-- l2 # adenauerring -->
#     </div>
#    </td>
#    <td class="mensadata">
#     <table border="0" cellpadding="0" cellspacing="0" class="easy-tab-dot">
#      <tr class="mt-1">
#       <td class="mtd-icon">
#        <div>
#         <img class="mealicon_2" src="/layout/icons/s_2.gif"/>
#         <br/>
#        </div>
#       </td>
#       <td class="first" valign="top">
#        <span class="bg">
#         <b>
#          Schweinebraten
#         </b>
#         <span>
#          Kartoffelpüree Zwiebelsoße
#         </span>
#        </span>
#        <sup>
#         [2,3,5,Ge,ML,Se,We]
#        </sup>
#       </td>
#       <td style="text-align: right;vertical-align:bottom;">
#        <span class="bgp price_1">
#         2,60 €
#        </span>
#        <span class="bgp price_2">
#         4,00 €
#        </span>
#        <span class="bgp price_3">
#         3,50 €
#        </span>
#        <span class="bgp price_4">
#         2,95 €
#        </span>
#       </td>
#      </tr>
#      <tr class="mt-6">
#       <td class="mtd-icon">
#        <div>
#         <img class="mealicon_2" src="/layout/icons/vegan_2.gif"/>
#         <br/>
#        </div>
#       </td>
#       <td class="first" valign="top">
#        <span class="bg">
#         <b>
#          Gemüseschnitzel mit Sweet Chilisoße und Duftreis
#         </b>
#        </span>
#        <sup>
#         [Sa,Se,So,We]
#        </sup>
#       </td>
#       <td style="text-align: right;vertical-align:bottom;">
#        <span class="bgp price_1">
#         2,60 €
#        </span>
#        <span class="bgp price_2">
#         4,00 €
#        </span>
#        <span class="bgp price_3">
#         3,50 €
#        </span>
#        <span class="bgp price_4">
#         2,95 €
#        </span>
#       </td>
#      </tr>
#      <tr class="mt-7">
#       <td class="mtd-icon">
#        <div>
#         <img class="mealicon_2" src="/layout/icons/vegetarian_2.gif"/>
#         <br/>
#        </div>
#       </td>
#       <td class="first" style="background:white;" valign="top">
#        <span class="bg">
#         <b>
#          zu jedem Gericht ein Birnenquark oder Obst
#         </b>
#        </span>
#        <sup>
#         [ML]
#        </sup>
#       </td>
#       <td style="text-align: right;vertical-align:bottom;background:white;">
#        <span class="bgp price_1">
#        </span>
#        <span class="bgp price_2">
#        </span>
#        <span class="bgp price_3">
#        </span>
#        <span class="bgp price_4">
#        </span>
#       </td>
#      </tr>
#     </table>
#    </td>
#   </tr>
#   <tr>
#    <td class="mensatype" style="white-space: normal !important;">
#     <div>
#      Linie 3
#      <!-- l3 # adenauerring -->
#     </div>
#    </td>
#    <td class="mensadata">
#     <table border="0" cellpadding="0" cellspacing="0" class="easy-tab-dot">
#      <tr>
#       <td class="mtd-icon">
#        <div>
#         <br/>
#        </div>
#       </td>
#       <td colspan="2" style="background:white">
#        <div style="display:block;background:white">
#         -
#        </div>
#       </td>
#      </tr>
#     </table>
#    </td>
#   </tr>
#   <tr>
#    <td class="mensatype" style="white-space: normal !important;">
#     <div>
#      Linie 4/5
#      <br/>
#      G&amp;G-Gerichte To-Go
#      <!-- l45 # adenauerring -->
#     </div>
#    </td>
#    <td class="mensadata">
#     <table border="0" cellpadding="0" cellspacing="0" class="easy-tab-dot">
#      <tr>
#       <td class="mtd-icon">
#        <div>
#         <br/>
#        </div>
#       </td>
#       <td colspan="2" style="background:white">
#        <div style="display:block;background:white">
#         -
#        </div>
#       </td>
#      </tr>
#     </table>
#    </td>
#   </tr>
#   <tr>
#    <td class="mensatype" style="white-space: normal !important;">
#     <div>
#      Schnitzelbar
#      <!-- schnitzelbar # adenauerring -->
#     </div>
#    </td>
#    <td class="mensadata">
#     <table border="0" cellpadding="0" cellspacing="0" class="easy-tab-dot">
#      <tr>
#       <td class="mtd-icon">
#        <div>
#         <br/>
#        </div>
#       </td>
#       <td colspan="2" style="background:white">
#        <div style="display:block;background:white">
#         -
#        </div>
#       </td>
#      </tr>
#     </table>
#    </td>
#   </tr>
#   <tr>
#    <td class="mensatype" style="white-space: normal !important;">
#     <div>
#      L6 Update
#      <!-- update # adenauerring -->
#     </div>
#    </td>
#    <td class="mensadata">
#     <table border="0" cellpadding="0" cellspacing="0" class="easy-tab-dot">
#      <tr>
#       <td class="mtd-icon">
#        <div>
#         <br/>
#        </div>
#       </td>
#       <td colspan="2" style="background:white">
#        <div style="display:block;background:white">
#         -
#        </div>
#       </td>
#      </tr>
#     </table>
#    </td>
#   </tr>
#   <tr>
#    <td class="mensatype" style="white-space: normal !important;">
#     <div>
#      Spätausgabe und Abendessen
#      <!-- abend # adenauerring -->
#     </div>
#    </td>
#    <td class="mensadata">
#     <table border="0" cellpadding="0" cellspacing="0" class="easy-tab-dot">
#      <tr>
#       <td class="mtd-icon">
#        <div>
#         <br/>
#        </div>
#       </td>
#       <td colspan="2" style="background:white">
#        <div style="display:block;background:white">
#         -
#        </div>
#       </td>
#      </tr>
#     </table>
#    </td>
#   </tr>
#   <tr>
#    <td class="mensatype" style="white-space: normal !important;">
#     <div>
#      [kœri]werk
#      <br/>
#      11-14 Uhr
#      <br/>
#      To-Go
#      <!-- aktion # adenauerring -->
#     </div>
#    </td>
#    <td class="mensadata">
#     <table border="0" cellpadding="0" cellspacing="0" class="easy-tab-dot">
#      <tr class="mt-2">
#       <td class="mtd-icon">
#        <div>
#         <img class="mealicon_2" src="/layout/icons/r_2.gif"/>
#         <br/>
#        </div>
#       </td>
#       <td class="first" valign="top">
#        <span class="bg">
#         <b>
#          Reine Kalbsbratwurst mit Currysoße und Baguette
#         </b>
#        </span>
#        <sup>
#         [Se,Sn,We]
#        </sup>
#       </td>
#       <td style="text-align: right;vertical-align:bottom;">
#        <span class="bgp price_1">
#         2,00 €
#        </span>
#        <span class="bgp price_2">
#         2,30 €
#        </span>
#        <span class="bgp price_3">
#         2,30 €
#        </span>
#        <span class="bgp price_4">
#         2,30 €
#        </span>
#       </td>
#      </tr>
#      <tr class="mt-6">
#       <td class="mtd-icon">
#        <div>
#         <img class="mealicon_2" src="/layout/icons/vegan_2.gif"/>
#         <br/>
#        </div>
#       </td>
#       <td class="first" valign="top">
#        <span class="bg">
#         <b>
#          Vegane Bratwurst mit Currysoße und Baguette
#         </b>
#        </span>
#        <sup>
#         [Se,Sn,So,We]
#        </sup>
#       </td>
#       <td style="text-align: right;vertical-align:bottom;">
#        <span class="bgp price_1">
#         2,00 €
#        </span>
#        <span class="bgp price_2">
#         2,30 €
#        </span>
#        <span class="bgp price_3">
#         2,30 €
#        </span>
#        <span class="bgp price_4">
#         2,30 €
#        </span>
#       </td>
#      </tr>
#      <tr class="mt-6">
#       <td class="mtd-icon">
#        <div>
#         <img class="mealicon_2" src="/layout/icons/vegan_2.gif"/>
#         <br/>
#        </div>
#       </td>
#       <td class="first" valign="top">
#        <span class="bg">
#         <b>
#          koerifrites
#         </b>
#        </span>
#       </td>
#       <td style="text-align: right;vertical-align:bottom;">
#        <span class="bgp price_1">
#         1,20 €
#        </span>
#        <span class="bgp price_2">
#         1,20 €
#        </span>
#        <span class="bgp price_3">
#         1,20 €
#        </span>
#        <span class="bgp price_4">
#         1,20 €
#        </span>
#       </td>
#      </tr>
#     </table>
#    </td>
#   </tr>
#   <tr>
#    <td class="mensatype" style="white-space: normal !important;">
#     <div>
#      Cafeteria
#      <!-- heisstheke # adenauerring -->
#     </div>
#    </td>
#    <td class="mensadata">
#     <table border="0" cellpadding="0" cellspacing="0" class="easy-tab-dot">
#      <tr>
#       <td class="mtd-icon">
#        <div>
#         <br/>
#        </div>
#       </td>
#       <td colspan="2" style="background:white">
#        <div style="display:block;background:white">
#         -
#        </div>
#       </td>
#      </tr>
#     </table>
#    </td>
#   </tr>
#   <tr>
#    <td class="mensatype" style="white-space: normal !important;">
#     <div>
#      Cafeteria
#      <br/>
#      11-14 Uhr
#      <!-- nmtisch # adenauerring -->
#     </div>
#    </td>
#    <td class="mensadata">
#     <table border="0" cellpadding="0" cellspacing="0" class="easy-tab-dot">
#      <tr>
#       <td class="mtd-icon">
#        <div>
#         <br/>
#        </div>
#       </td>
#       <td colspan="2" style="background:white">
#        <div style="display:block;background:white">
#         -
#        </div>
#       </td>
#      </tr>
#     </table>
#    </td>
#   </tr>
#   <tr>
#    <td class="mensatype" style="white-space: normal !important;">
#     <div>
#      [pizza]werk
#      <br/>
#      Pizza
#      <br/>
#      11-14 Uhr
#      <br/>
#      To-Go
#      <!-- pizza # adenauerring -->
#     </div>
#    </td>
#    <td class="mensadata">
#     <table border="0" cellpadding="0" cellspacing="0" class="easy-tab-dot">
#      <tr class="mt-0">
#       <td class="mtd-icon">
#        <div>
#         <br/>
#        </div>
#       </td>
#       <td class="first" valign="top">
#        <span class="bg">
#         <b>
#          Pizza Gyros - Pizza mit Hähnchengyros, Peperoni und roten Zwiebeln
#         </b>
#        </span>
#        <sup>
#         [Ei,ML,Se,We]
#        </sup>
#       </td>
#       <td style="text-align: right;vertical-align:bottom;">
#        <span class="bgp price_1">
#         4,45 €
#        </span>
#        <span class="bgp price_2">
#         8,90 €
#        </span>
#        <span class="bgp price_3">
#         6,10 €
#        </span>
#        <span class="bgp price_4">
#         5,15 €
#        </span>
#       </td>
#      </tr>
#      <tr class="mt-7">
#       <td class="mtd-icon">
#        <div>
#         <img class="mealicon_2" src="/layout/icons/vegetarian_2.gif"/>
#         <br/>
#        </div>
#       </td>
#       <td class="first" valign="top">
#        <span class="bg">
#         <b>
#          Pizza Funghi - frische Champignons, Frühlingszwiebeln
#         </b>
#        </span>
#        <sup>
#         [ML,We]
#        </sup>
#       </td>
#       <td style="text-align: right;vertical-align:bottom;">
#        <span class="bgp price_1">
#         4,25 €
#        </span>
#        <span class="bgp price_2">
#         8,50 €
#        </span>
#        <span class="bgp price_3">
#         5,85 €
#        </span>
#        <span class="bgp price_4">
#         4,90 €
#        </span>
#       </td>
#      </tr>
#      <tr class="mt-6">
#       <td class="mtd-icon">
#        <div>
#         <img class="mealicon_2" src="/layout/icons/vegan_2.gif"/>
#         <br/>
#        </div>
#       </td>
#       <td class="first" valign="top">
#        <span class="bg">
#         <b>
#          Pizza Funghi vegan - frische Champignons, Frühlingszwiebeln
#         </b>
#        </span>
#        <sup>
#         [1,2,We]
#        </sup>
#       </td>
#       <td style="text-align: right;vertical-align:bottom;">
#        <span class="bgp price_1">
#         4,25 €
#        </span>
#        <span class="bgp price_2">
#         8,50 €
#        </span>
#        <span class="bgp price_3">
#         5,85 €
#        </span>
#        <span class="bgp price_4">
#         4,90 €
#        </span>
#       </td>
#      </tr>
#      <tr class="mt-0">
#       <td class="mtd-icon">
#        <div>
#         <img class="mealicon_2" src="/layout/icons/vegetarian_2.gif"/>
#         <br/>
#        </div>
#       </td>
#       <td class="first" valign="top">
#        <span class="bg">
#         <b>
#          Pizza Margherita - frische Tomaten mit Mozzarella und Basilikumpesto
#         </b>
#        </span>
#        <sup>
#         [2,Ei,LAB,ML,We]
#        </sup>
#       </td>
#       <td style="text-align: right;vertical-align:bottom;">
#        <span class="bgp price_1">
#         3,95 €
#        </span>
#        <span class="bgp price_2">
#         7,90 €
#        </span>
#        <span class="bgp price_3">
#         5,45 €
#        </span>
#        <span class="bgp price_4">
#         4,55 €
#        </span>
#       </td>
#      </tr>
#      <tr class="mt-6">
#       <td class="mtd-icon">
#        <div>
#         <img class="mealicon_2" src="/layout/icons/vegan_2.gif"/>
#         <br/>
#        </div>
#       </td>
#       <td class="first" valign="top">
#        <span class="bg">
#         <b>
#          Pizza Margherita - frische Tomaten und Basilikumpesto
#         </b>
#        </span>
#        <sup>
#         [1,2,Ha,We]
#        </sup>
#       </td>
#       <td style="text-align: right;vertical-align:bottom;">
#        <span class="bgp price_1">
#         3,95 €
#        </span>
#        <span class="bgp price_2">
#         7,90 €
#        </span>
#        <span class="bgp price_3">
#         5,45 €
#        </span>
#        <span class="bgp price_4">
#         4,55 €
#        </span>
#       </td>
#      </tr>
#     </table>
#    </td>
#   </tr>
#   <tr>
#    <td class="mensatype" style="white-space: normal !important;">
#     <div>
#      [pizza]werk
#      <br/>
#      Pasta
#      <!-- pasta # adenauerring -->
#     </div>
#    </td>
#    <td class="mensadata">
#     <table border="0" cellpadding="0" cellspacing="0" class="easy-tab-dot">
#      <tr>
#       <td class="mtd-icon">
#        <div>
#         <br/>
#        </div>
#       </td>
#       <td colspan="2" style="background:white">
#        <div style="display:block;background:white">
#         -
#        </div>
#       </td>
#      </tr>
#     </table>
#    </td>
#   </tr>
#   <tr>
#    <td class="mensatype" style="white-space: normal !important;">
#     <div>
#      [pizza]werk
#      <br/>
#      Salate / Vorspeisen
#      <!-- salat_dessert # adenauerring -->
#     </div>
#    </td>
#    <td class="mensadata">
#     <table border="0" cellpadding="0" cellspacing="0" class="easy-tab-dot">
#      <tr>
#       <td class="mtd-icon">
#        <div>
#         <br/>
#        </div>
#       </td>
#       <td colspan="2" style="background:white">
#        <div style="display:block;background:white">
#         -
#        </div>
#       </td>
#      </tr>
#     </table>
#    </td>
#   </tr>
#  </table>
# </div>
